   299.0    65.2       2
   290.1    69.1       2
   288.9    67.9       2
   288.8    68.2       2
   283.2    61.0       2
   293.2    58.4       2
   285.3    67.3       2
   284.1    65.7       2
   281.4    67.7       2
   286.1    61.4       2
   284.9    62.3       2
   284.8    68.1       2
   296.0    62.0       2
   282.9    71.8       2
   280.9    67.8       2
   291.2    62.0       2
   292.8    62.2       2
   291.0    61.9       2
   285.7    62.4       2
   283.9    62.9       2
   298.4    61.5       2
   285.1    65.3       2
   286.1    60.1       2
   283.1    65.4       2
   289.4    58.3       2
   284.6    70.7       2
   296.6    62.3       2
   295.9    64.9       2
   295.2    62.8       2
   293.9    54.5       2
   275.0    65.5       2
   286.8    69.5       2
   291.1    64.4       2
   284.8    62.5       2
   283.7    59.5       2
   295.4    66.9       2
   291.8    62.7       2
   274.9    72.3       2
   302.9    61.2       2
   272.1    80.4       2
   274.9    74.9       2
   296.3    59.4       2
   286.2    58.8       2
   294.2    63.3       2
   284.1    66.5       2
   299.2    62.4       2
   275.4    71.0       2
   273.2    70.9       2
   281.6    65.9       2
   295.7    55.3       2
   287.1    56.8       2
   287.7    66.9       2
   296.7    53.7       2
   282.2    64.2       2
   291.7    65.6       2
   281.6    73.4       2
   311.0    56.2       2
   278.6    64.7       2
   288.0    65.7       2
   276.7    72.1       2
   292.0    62.0       2
   286.4    69.9       2
   292.7    65.7       2
   294.2    62.9       2
   278.6    59.6       2
   283.1    69.2       2
   284.1    66.0       2
   278.6    73.6       2
   291.1    60.4       2
   294.6    59.4       2
   274.3    70.5       2
   274.0    57.1       2
   283.8    62.7       2
   272.7    66.9       2
   303.2    58.3       2
   282.0    70.4       2
   281.9    61.0       2
   287.0    59.9       2
   293.5    63.8       2
   283.6    56.3       2
   296.9    55.3       2
   290.9    58.2       2
   303.0    58.1       2
   292.8    61.1       2
   281.1    65.0       2
   293.0    61.1       2
   284.0    66.5       2
   279.8    66.7       2
   292.9    65.4       2
   284.0    66.9       2
   282.0    64.5       2
   280.6    64.0       2
   287.7    63.4       2
   287.7    63.4       2
   298.3    59.5       2
   299.6    53.4       2
   291.3    62.5       2
   295.2    61.4       2
   288.0    62.4       2
   297.8    59.5       2
   286.0    62.6       2
   285.3    66.2       2
   286.9    63.4       2
   275.1    73.7       2
"""

datF = []
datM = []
dat = []

for line in data.split('\n'):
    cols = line.split()
    if not cols:
        continue
    if cols[2] == '1':
        datF.append((float(cols[0]), float(cols[1])))
    elif cols[2] == '2':
        datM.append((float(cols[0]), float(cols[1])))
    dat.append((float(cols[0]), float(cols[1]), float(cols[2])))

# %%
import matplotlib.pyplot as plt

xM = [row[0] for row in datM]
yM = [row[1] for row in datM]
plt.scatter(xM, yM, c='b')
xF = [row[0] for row in datF]
yF = [row[1] for row in datF]
plt.scatter(xF, yF, c='r')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

trainM = [[row[0]] for row in datM]
testM = [row[1] for row in datM]

regM = LinearRegression().fit(trainM, testM)
print('Mscore', regM.score(trainM, testM))
print('Mcoef', regM.coef_)
print('Mparams', regM.get_params())
print('Mintercept', regM.intercept_)

trainF = [[row[0]] for row in datF]
testF = [row[1] for row in datF]

regF = LinearRegression().fit(trainF, testF)
print('Fscore', regF.score(trainF, testF))
print('Fcoef', regF.coef_)
print('Fparams', regF.get_params())
print('Fintercept', regF.intercept_)

plt.plot(xF, regF.predict(trainF), color='g')
plt.scatter(xF, yF, c='g')
plt.plot(xM, regM.predict(trainM), color='b')
plt.scatter(xM, yM, c='b')
plt.show()
# Out:
# Mscore 0.36917632936480155
# Mcoef [-0.38788717]
# Mparams {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}
# Mintercept 174.92546067591084
# Fscore 0.1781828649274786
# Fcoef [-0.2564907]
# Fparams {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}
# Fintercept 130.89331457742142

# %%
import math
print('Predict female with 260 yards:', regF.predict([[260]]))
p = regF.predict([[260]])
s = regF.score(trainF, testF)
stdev = np.std(regF.predict(trainF))
print('score is', s)
print('Std dev is:', stdev)
interval = 1.96 * stdev
print('95% confidence interval for the above:', p - interval, p + interval)
# Out:
# Predict female with 260 yards: [64.20573229]
# score is 0.1781828649274786
# Std dev is: 2.4273032097039113
# 95% confidence interval for the above: [59.448218] [68.96324658]

# %%
from sklearn.linear_model import LinearRegression

trainMF = [[row[0], row[2]] for row in dat]
testMF = [row[1] for row in dat]

regMF = LinearRegression().fit(trainMF, testMF)
print('score', regMF.score(trainMF, testMF))
print('coef', regMF.coef_)
print('params', regMF.get_params())
print('intercept', regMF.intercept_)

x = [row[0] for row in dat]
plt.scatter(x, testMF, c='g')
print('predictions', regMF.predict(trainMF))
plt.plot(x, regMF.predict(trainMF), color='b')
plt.show()
# Out:
# score 0.358876658102723
# coef [-0.32284215  8.94888186]
# params {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}
# intercept 138.320055542989
# predictions [68.75372582 65.10560949 65.5575885  73.62864233 69.52854698 68.49545209
#  64.00794617 64.68591469 66.59068339 66.13870438 68.36631523 67.6560625
#  70.04509443 71.01362089 60.84409307 71.30417882 66.84895711 69.980526
#  68.43088366 63.42683029 60.58581935 67.13951505 67.46235721 70.8199156
#  70.36793658 73.24123174 65.5575885  65.91271487 63.52368294 74.08062134
#  65.07332527 66.88124133 68.23717837 67.75291514 67.13951505 70.6262103
#  68.04347308 68.10804151 68.56002053 66.17098859 64.65363048 71.30417882
#  63.94337774 68.97971532 68.39859945 66.23555702 62.1677459  67.75291514
#  65.17017792 68.94743111 67.55920985 68.7214416  68.65687317 70.88448403
#  69.980526   66.78438868 65.39616743 60.74724043 67.81748357 67.81748357
# ...
